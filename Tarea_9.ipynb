# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelVeltmann/edd_1358_2021/blob/master/Tarea_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Queue:
  def __init__(self):
    self.__data = list()
    

  def is_empty(self):
    return len(self.__data) == 0

  def lenght(self):
    return len(self.__data)

  def enqueue(self, item):
    self.__data.append(item)

  def dequeue(self):
    if not self.is_empty():
      return self.__data.pop(0)
    else:
      return None

  def to_string(self):
    cadena = ""
    for elem in self.__data:
      cadena = cadena +"|" + elem
    cadena = cadena +"|"
    return cadena

# %%
class BoundedPriorityQueue:
  def __init__(self, niveles):
    self.__niveles = niveles
    self.__data = [Queue() for x in range(niveles) ]
    self.__size = 0

  def is_empty(self):
    return self.__size == 0

  def lenght(self):
    return self.__size

  def enqueue(self, prioridad, elem ):
    if prioridad < len(self.__data) and prioridad >= 0:
      self.__data[prioridad].enqueue(elem)
      self.__size +=1
    else:
      print("Prioridad fuera de rango.")

  def dequeue(self):
    if not self.is_empty():
      nivel = 0
      while self.__data[nivel].is_empty():
        nivel +=1
      return self.__data[nivel].dequeue()

  def to_string( self ):
      for nivel in range(len(self.__data)):
        print(f"Nivel {nivel} --> {self.__data[nivel].to_string()}")

  def vaciar_lista(self):
    nivel = 0
    self.to_string()
    while not self.is_empty() and nivel < self.__niveles:
      if self.__data[nivel].is_empty():
        nivel += 1
      else:
        while not self.__data[nivel].is_empty():
          self.__data[nivel].dequeue()
          self.to_string()
    print("La lista esta vacia")

# %%
cpa = BoundedPriorityQueue(6)
cpa.enqueue(4, "Timonel")
cpa.enqueue(3, "Hombres")
cpa.enqueue(1, "Niñas")
cpa.enqueue(2, "3ra Edad")
cpa.enqueue(3, "Mujeres")
cpa.enqueue(4, "Mecanico")
cpa.enqueue(4, "Vigia")
cpa.enqueue(2, "Niños")
cpa.enqueue(4, "Maestre")
cpa.enqueue(5, "Capitan")
cpa.to_string()
print("Vaciando el Barco")
cpa.vaciar_lista()
print("El barco esta vacio")
# Out:
# Nivel 0 --> |
# Nivel 1 --> |Niñas|
# Nivel 2 --> |3ra Edad|Niños|
# Nivel 3 --> |Hombres|Mujeres|
# Nivel 4 --> |Timonel|Mecanico|Vigia|Maestre|
# Nivel 5 --> |Capitan|
# Vaciando el Barco
# Nivel 0 --> |
# Nivel 1 --> |Niñas|
# Nivel 2 --> |3ra Edad|Niños|
# Nivel 3 --> |Hombres|Mujeres|
# Nivel 4 --> |Timonel|Mecanico|Vigia|Maestre|
# Nivel 5 --> |Capitan|
# Nivel 0 --> |
# Nivel 1 --> |
# Nivel 2 --> |3ra Edad|Niños|
# Nivel 3 --> |Hombres|Mujeres|
# Nivel 4 --> |Timonel|Mecanico|Vigia|Maestre|
# Nivel 5 --> |Capitan|
# Nivel 0 --> |
# Nivel 1 --> |
# Nivel 2 --> |Niños|
# Nivel 3 --> |Hombres|Mujeres|
# Nivel 4 --> |Timonel|Mecanico|Vigia|Maestre|
# Nivel 5 --> |Capitan|
# Nivel 0 --> |
# Nivel 1 --> |
# Nivel 2 --> |
# Nivel 3 --> |Hombres|Mujeres|
# Nivel 4 --> |Timonel|Mecanico|Vigia|Maestre|
# Nivel 5 --> |Capitan|
# Nivel 0 --> |
# Nivel 1 --> |
# Nivel 2 --> |
# Nivel 3 --> |Mujeres|
# Nivel 4 --> |Timonel|Mecanico|Vigia|Maestre|
# Nivel 5 --> |Capitan|
# Nivel 0 --> |
# ...
